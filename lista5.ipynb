# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoipro/ADS025/blob/master/lista5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: FELIPE DE OLIVEIRA SANTOS
# Lista 5

'''# Exercicios 01:

import statistics
from scipy.stats.mstats import gmean

l1 = [10, 13, 17, 9, 8, 11, 13, 7]

Med_simp = statistics.mean(l1)
print('A Média aritimetica simples é:', round(Med_simp,2))

Med_harm = statistics.harmonic_mean(l1)
print('A Média Harmônica é', round(Med_harm,2))

Med_geom = gmean(l1)
print('A média geométrica é:', round(Med_geom,2))

Moda = statistics.mode(l1)
print('A moda é:', Moda)

Var = statistics.variance(l1)
print('A variância é:', round(Var,2))

Desv = statistics.stdev(l1)
print('O desvio padrão é:', round(Desv,2))
'''
'''# Exercicios 02:

import statistics
from scipy.stats.mstats import gmean

l1 = [67, 75, 63, 72, 77, 78, 81, 77, 80]

Med_simp = statistics.mean(l1)
print('A Média aritimetica simples é:', round(Med_simp,2))

Med_harm = statistics.harmonic_mean(l1)
print('A Média Harmônica é', round(Med_harm,2))

Med_geom = gmean(l1)
print('A média geométrica é:', round(Med_geom,2))

Moda = statistics.mode(l1)
print('A moda é:', Moda)

Mediana = statistics.median(l1)
print('A mediana é:', Mediana)

Var = statistics.variance(l1)
print('A variância é:', round(Var,2))

Desv = statistics.stdev(l1)
print('O desvio padrão é:', round(Desv,2))
'''
'''# Exercicios 03:

import statistics

l1 = [4.0, 4.5, 5.0, 5.0, 5.0, 5.5, 6.0, 6.0, 
      6.5, 6.5, 6.5, 6.5, 7.0, 7.0, 7.0, 7.0, 
      7.0, 7.5, 8.5, 9.0, 9.0, 9.0, 9.5, 10.0, 
      10.0, 10.5, 11.0, 12.0, 12.5, 13.0, 13.0]

Med_simp = statistics.mean(l1)

Desv = statistics.stdev(l1)

CV = Desv/Med_simp
print('O Coeficiente de Variação é:', round(100*CV,2),'%')
'''
'''# Exercicios 04:

import statistics
from scipy.stats.mstats import gmean

l1 = [12, 15, 18, 22, 17, 14, 18, 23, 29, 12]

Med_simp = statistics.mean(l1)
print('O valor da produção media é:', round(Med_simp,2))

Mediana = statistics.median(l1)
print('O valor da mediana da produção é:', Mediana)

Desv = statistics.stdev(l1)
print('O valor do desvio padrão da produção é:', round(Desv,2))
'''

'''# Exercicios 05:

import statistics
from scipy.stats.mstats import gmean


n = float(input('Insira um número entre 0 e 10: '))
if n<-1 or n>10:
  while True:
    print('Número errado!')
    n = int(input('Insira um número entre 0 e 10: '))
if n>10:
  soma=0

Med_simp = statistics.mean(n)
print('O valor da produção media é:', round(Med_simp,2))

Mediana = statistics.median(n)
print('O valor da mediana da produção é:', Mediana)

Desv = statistics.stdev(n)
print('O valor do desvio padrão da produção é:', round(Desv,2))
'''

# Exercicios 06:

import statistics
from scipy.stats.mstats import gmean


n1 = float(input('Insira a primeira nota do aluno (entre 0 e 10): '))
n2 = float(input('Insira a segunda nota do aluno (entre 0 e 10): '))
n3 = float(input('Insira a terceira nota do aluno (entre 0 e 10): '))

if n1<-1 or n1>10:
  while True:
    print('Número errado!')
    n1 = int(input('Insira a primeira nota do aluno (entre 0 e 10): '))
if n2<-1 or n2>10:
  while True:
    print('Número errado!')
    n1 = int(input('Insira a segunda nota do aluno (entre 0 e 10): '))
if n3<-1 or n3>10:
  while True:
    print('Número errado!')
    n1 = int(input('Insira a terceira nota do aluno (entre 0 e 10): '))
if n1>=0 and n1<=10:
    mediapon = (n1*3 + n2*4 + n3*3) / (3+4+3)
    print('A media ponderada das notas é: ',mediapon)
# Out:
# Insira a primeira nota do aluno (entre 0 e 10): 10
# Insira a segunda nota do aluno (entre 0 e 10): 5
# Insira a terceira nota do aluno (entre 0 e 10): 6
# A media ponderada das notas é:  6.8
