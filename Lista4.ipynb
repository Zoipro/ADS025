# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoipro/ADS025/blob/master/Lista4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: FELIPE DE OLIVEIRA SANTOS
# Lista 4

# Exercicios 01:
''''
num_lados = int(input('Informe o numero de lados do poligono: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário
tam_lados = int(input('Informe a medida do lados (em cm) do poligono: ')) # grava no endereça da variável tam_lados o valor int informado pelo usuário

if num_lados == 3:
       print('O poligono é um TRIÂNGULO, e o valor da AREA é',tam_lados,'cm')
if num_lados == 4:
       print('O poligono é um QUADRADO, e o valor da AREA é',tam_lados,'cm')
if num_lados == 5:
       print('O poligono é um PENTáGONO, e o valor da AREA é',tam_lados,'cm')

'''
# Exercicios 02:
''''
num_lados = int(input('Informe o numero de lados do poligono: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário
tam_lados = int(input('Informe a medida do lados (em cm) do poligono: ')) # grava no endereça da variável tam_lados o valor int informado pelo usuário


while (num_lados < 3):
       print('Não é um Poligono!')
       break;

while (tam_lados > 5):
       print('Poligono não Identificado!')
       break;

if num_lados == 3 and tam_lados <= 5:
       print('O poligono é um TRIÂNGULO, e o valor da AREA é',tam_lados,'cm')
if num_lados == 4 and tam_lados <= 5:
       print('O poligono é um QUADRADO, e o valor da AREA é',tam_lados,'cm')
if num_lados == 5 and tam_lados <= 5:
       print('O poligono é um PENTáGONO, e o valor da AREA é',tam_lados,'cm')

'''
# Exercicios 03:
''''
valor1 = int(input('Digite valor 1: '))
valor2 = int(input('Digite valor 2: '))
valor3 = int(input('Digite valor 3: '))

while valor1 == valor2:
       
           valor2 = int(input('Digite um Valor diferente para o 2: '))

while valor1 == valor3:
           valor3 = int(input('Digite um Valor diferente para o 3: '))

while valor2 == valor3:
           valor3 = int(input('Digite um Valor diferente para o 3: '))


if (valor1 > valor2) and (valor2 > valor3):
  print('O maior valor é o 1ª:',valor1)
elif (valor2 > valor1) and (valor1 > valor3):
  print('O maior valor é o 2ª:',valor2)
else:
  print('O maior valor é o 3ª:',valor3)
 '''''
 # Exercicios 04:
''''
m1 = int(input('Digite a primeira medida do lado triagulo: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário
m2 = int(input('Digite a segunda medida do lado triagulo: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário
m3 = int(input('Digite a terceira medida do lado triagulo: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário

if m1 == m2 and m1 == m3 and m2 == m3:
       print('O poligono é um Triângulo Equilátero e possui os 3 lados iguais.')
if m1 == m2 and m1 == m3 and m3 != m2 or m1 == m3:
       print('O poligono é um Triângulo Isóscele e possui os 2 lados iguais.')
if m1 != m2 and m1 != m3 and m2 != m3:
       print('O poligono é um Triângulo Escaleno e possui 3 lados diferentes.')
''''''
# Exercicios 05:
'''''''
a1 = int(input('Digite o primeiro angulo do Triangulo: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário
a2 = int(input('Digite o segundo angulo do Triangulo: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário
a3 = int(input('Digite o terceiro angulo do Triangulo: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário

if a1 == 90 or a2 == 90 or a3 == 90:
       print('O poligono é um Triangulo Retângulo e possui um ângulo reto. (igual a 90º)')
if a1 > 90 or a2 > 90 or a3 > 90:
       print('O poligono é um Triângulo Obtusângulo e possui um ângulo obtuso. (maior que90º)')
if a1 < 90 or a2 < 90 or a3 < 90:
       print('O poligono é um Triângulo Acutângulo e possui três ângulos agudos. (menor que 90º)')
'''''
# Exercicios 06:
'''''
n = int(input('Informa um numero: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário

for (n=1;n<=max;n++){
    
     print('Numeros gerados:',n)
}
'''''
# Exercicios 07:
'''''
n1 = int(input('Informe um numero entre 1 e 4: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário


while n1 <1 or n1 >4:
       n1 = int(input('"entrada inválida"! Digite o numero novamente: '))
else:
       print('O numero digitado é:',n1)
'''''''''''
# Exercicios 08:

soma=0;
cont=0;

n1 = int(input('Informe um numero: ')) # grava no endereça da variável num_lados o valor int informado pelo usuário


if n1 %3==0 and n1!=0:
      soma=soma+n1; cont++;
while (num!=0)
# Out:
#   File "<ipython-input-20-4e67e34ccb6f>", line 119
#     soma=soma+n1; cont++;
#                         ^
# SyntaxError: invalid syntax

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Nova seção

# %%
# crie uma lista ordenada de maneira aleatória com
# valores não repetidos e na faixa de 1 até 10
'''from random import shuffle
num = list(range(1,11))
print(num)
shuffle(num)
print(num)'''

# Crie uma variável inteira que tenha 1 valor aleatório entre 0 e 10:
'''from random import randint
num = randint(0,10)
print(num)'''

# Simule o experimento de lançamento de moeda, com resultado cara ou coroa.
# O usuário deve inserir a quantidade de lanbçamentos.
'''
from random import randint
qde = int(input('Insira a quantidade de lançamentos de moedas: '))
cont_ca_co = [0]*2 # --> [0, 0]
for _ in range(0,qde):
  sorteio = randint(0,1) # 0 vai representar CARA e 1 COROA
  cont_ca_co[sorteio] += 1 # cont_ca_co[sorteio] = cont_ca_co[sorteio] + 1
print('Tivemos', cont_ca_co[0], 'caras e ',cont_ca_co[1], 'coroas')
print('A probabilidade de ser cara é', round(cont_ca_co[0]/qde,3))
print('A probabilidade de ser coroa é', round(cont_ca_co[1]/qde,3))'''

# Simule o experimento de lançamento de dado, com os 6 resultados.
# O usuário deve inserir a quantidade de lançamentos.
'''from random import randint
qde = int(input('Insira a quantidade de lançamentos de dado: '))
cont = [0]*6 # --> [0, 0, 0, 0, 0, 0]
for _ in range(0,qde):
  sorteio = randint(0,5) # 0, 1, 2, 3, 4, 5
  cont[sorteio] += 1 # cont_ca_co[sorteio] = cont_ca_co[sorteio] + 1
print('A probabilidade de ser UM é', round(cont[0]/qde,3))
print('A probabilidade de ser DOIS é', round(cont[1]/qde,3))
print('A probabilidade de ser TRÊS é', round(cont[2]/qde,3))
print('A probabilidade de ser QUATRO é', round(cont[3]/qde,3))
print('A probabilidade de ser CINCO é', round(cont[4]/qde,3))
print('A probabilidade de ser SEIS é', round(cont[5]/qde,3))'''

# Crie 1 variável que tenha como resultado um número REAL
# entre 0 e 0,1:
'''import random
x = random.uniform(0,10)
print(type(x))
print(x)'''

# Crie uma lista com números pseudo-aleatórios entre 0 e 10 com
# 3 casas decimais. O usuário deverá informar o tamanho da lista
'''import random
qde = int(input('Insira o tamanho da lista: '))
lista = []
for _ in range(0,qde):
  lista.append(round(random.uniform(0,10),3))
print(lista)'''

'''lista = [_*_ for _ in range(0,11)]
print(lista)'''

# Ex 1 slide 22
'''ano = int(input('Insira sua idade em anos: '))
mes = int(input('Insira quantos meses completos se passaram desde seu aniversário: '))
dia = int(input('Insira quantos dias se passaram se seu aniversário fosse nesse mês: '))
if ano<0 or ano>120 or mes<0 or mes>11 or dia>29 or dia<0:
  while True:
    print('Dados errados!')
    ano = int(input('Insira sua idade em anos: '))
    mes = int(input('Insira quantos meses completos se passaram desde seu aniversário: '))
    dia = int(input('Insira quantos dias se passaram se seu aniversário fosse nesse mês: '))
    if ano>=0 and ano<=120 and mes>=0 and mes<=11 and dia<=29 and dia>=0:
      break
print('Sua idade em dias é:', ano*365+mes*30+dia)'''

# Ex 3 slide 22:
'''saldo = int(input('Insira o saldo: R$'))
print('Saldo reajustado:', saldo*1.01)'''

# Ex 4, slide 22:
'''ipi = int(input('Insira a porcentagem do IPI: '))
vp1 = float(input('Insira o valor unitário da peça 1: R$'))
qp1 = int(input('Insira a quantidade de peças 1 que serão vendidas: '))
vp2 = float(input('Insira o valor unitário da peça 2: R$'))
qp2 = int(input('Insira a quantidade de peças 2 que serão vendidas: '))
print('O custo total da sua compra é: ', round((vp1*qp1 + vp2*qp2)*(ipi/100 + 1),2))'''

# Ex 5, slide 22:
'''sal = float(input('Insira quanto você ganha por mês: R$'))
print('Você ganha R$', round(sal/1045,2), 'salários mínimos')'''

# Ex 6, slide 22:
'''num = int(input('Insira um número inteiro: '))
print('O número antecessor é', num-1, 'e o número sucessor é', num+1,)'''

# Ex 7, slide 23:
'''num1 = float(input('Insira o primeiro número: '))
num2 = float(input('Insira o segundo número: '))
print('O maior número é', max(num1,num2))'''

# Ex 8, slide 23:
'''idade = int(input('Insira sua idade em anos: '))
if idade<0 or idade>120:
  while True:
    print('Idade errada!')
    idade = int(input('Insira sua idade em anos: '))
    if idade>=0 and idade<=120:
      break
if idade>=16:
  print('A pessoa pode votar!')
else:
  print('A pessoa não pode votar!')'''

# Ex 9, slide 23:
'''senha = input('Insira a senha: ')
if senha == '1234':
  print('Acesso Permitido!')
else:
  print('Acesso Negado!')'''

'''qde = int(input('Insira a quantidade de maçãs desejadas: '))
if qde<12:
  print('O valor da sua compra foi R$', qde*.3)
else:
  print('O valor da sua compra foi R$', qde*.25)'''

# Ex 11, slide 23
'''num1 = float(input('Insira o primeiro número: '))
num2 = float(input('Insira o segundo número: '))
num3 = float(input('Insira o terceiro número: '))
lista = [num1, num2, num3]
lista.sort()
print('Os números ordenados são:', lista[0],',', lista[1], 'e', lista[2])'''

# Ex 12, slide 23
'''sexo = input('Insira o sexo, (1) para feminino e (2) para masculino: ')
if sexo!='1' and sexo!='2':
  while True:
    print('Insira o sexo válido!')
    sexo = input('Insira o sexo, (1) para feminino e (2) para masculino: ')
    if sexo=='1' or sexo=='2':
      break
alt = float(input('Insira a altura: '))
if sexo=='1':
  print('O peso ideal dela é:', round(62.1*alt-44.7,2))
else:
  print('O peso ideal dele é:', round(72.7*alt-58,2))'''

# Ex 14, slide 24
'''num = int(input('Insira um número inteiro: '))
for _ in range(0,11): # O _ ficará entre 0 e 10
  print(num, 'x', _, '=', num*_)'''

# Ex 15, slide 24
# Exemplo: n = 9 --> 2+4+6+8 = 20
'''n = int(input('Insira um número inteiro maior que 2: '))
if n<=2:
  while True:
    print('Número errado!')
    n = int(input('Insira um número inteiro maior que 2: '))
    if n>2:
      break
soma=0
for _ in range(2,n+1,2): # Ex n=9 --> 2,4,6,8
  soma += _  # soma = soma + _
print('A soma dos números pares até', n, 'é:', soma)'''
# range(2,10,2) --> começar em 2, vai até 10-1 = 9, pula de 2 em 2
# 1º soma = 0+2 = 2
# 2º soma = 2+4 = 6
# 3º soma = 6+6 = 12
# 4º soma = 12+8 = 20

# Ex 16, slide 16:
n = int(input('Insira um número inteiro maior que 1: '))
if n<=1:
  while True:
    print('Número errado!')
    n = int(input('Insira um número inteiro maior que 1: '))
    if n>1:
      break
soma=0
for _ in range(1,n+1,2): # Ex n=9 --> 1,3,5,7,9 --> 1+3+5+7+9 = 25
  soma += _  # soma = soma + _
print('A soma dos números ímpares até', n, 'é', soma)
